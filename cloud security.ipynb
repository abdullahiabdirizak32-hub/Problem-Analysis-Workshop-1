# %% [markdown]
# The following program displays a table with all the cloud security attack techniques, their detection methods and what solutions to be implemented

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Attack_Dataset.csv')

# Filter for Cloud security category
cloud_df = df[df['Category'].str.lower() == 'cloud security']

# Select relevant columns
columns = [
    'ID', 'Title', 'Category', 'Scenario Description',
    'Vulnerability', 'Detection Method', 'Solution'
]
cloud_table = cloud_df[columns]

# Display the table
cloud_table
# Out:
#         ID                                         Title        Category  \
# 753    754                QR Code Phishing for SSO Login  Cloud Security
# 754    755         Local Token Cache / Keychain Stealing  Cloud Security
# 755    756  Malicious Image with Pre-installed Backdoors  Cloud Security
# 756    757      Misconfigured Security Defaults in Image  Cloud Security
# 757    758          Exposed API Keys or Secrets in Image  Cloud Security
# ...    ...                                           ...             ...
# 2248  2249              LLM Orchestrator Running as Root  Cloud Security
# 2249  2250   Public Crawlers Can Access Agent Workspaces  Cloud Security
# 2250  2251  No Input Validation in Function-Calling Tool  Cloud Security
# 2251  2252                  Overprivileged API Key Usage  Cloud Security
# 2252  2253          Hardcoded Credentials in LLM Tooling  Cloud Security
#
#                                    Scenario Description  \
# 753   The attacker tricks a user into scanning a mal...
# 754   Tokens or credentials cached in local keychain...
# 755   In this attack, the attacker uploads a public ...
# 756   An attacker or even a careless developer publi...
# 757   In this attack, the threat actor identifies an...
# ...                                                 ...
# 2248  An AI orchestrator or LangChain/agent server i...
# 2249  Developers expose their agent's workspaces or ...
# 2250  LangChain or plugin tool takes user input and ...
# 2251  An application uses an API key with too many p...
# 2252  Developers often embed API keys or passwords d...
#
#                                           Vulnerability  \
# 753   QR login flow lacks binding to originating use...
# 754   Tokens stored locally without device/session/I...
# 755                  Trusted Image with Hidden Payloads
# 756                  Weak Security Defaults in VM Image
# 757                 Credentials hardcoded in filesystem
# ...                                                 ...
# 2248                             Cloud VMs, LLM servers
# 2249       Lack of file access control or crawler rules
# 2250         Missing input sanitization or restrictions
# 2251                 Too much access granted to API key
# 2252                   Hardcoded secrets in source code
#
#                                        Detection Method  \
# 753   Detect unusual logins via QR/device flow, shor...
# 754   Monitor credential store reads, unusual token ...
# 755   CloudTrail logs, network traffic inspection, E...
# 756   Scan image baseline, SSH audit tools, cloud co...
# 757       File scans, secret scanning tools, CloudTrail
# ...                                                 ...
# 2248      Full server takeover via single agent exploit
# 2249  Use Google Search Console to check indexed fil...
# 2250  Log and review all user inputs; enforce argume...
# 2251  Scan codebase for secrets; review cloud logs f...
# 2252  Monitor GitHub commits; scan for secrets with ...
#
#                                                Solution
# 753   Disable QR-based login unless required, bind d...
# 754   Encrypt credential stores, rotate tokens often...
# 755   Use only vetted images, scan marketplace image...
# 756   Create hardened base images, enforce scanning,...
# 757   Scan images for secrets before publish, use au...
# ...                                                 ...
# 2248  Check for agent user privileges; use monitorin...
# 2249  Add robots.txt to block crawlers; protect /upl...
# 2250  Use input validators (e.g., pydantic); never l...
# 2251  Use least privilege on all API keys; rotate ke...
# 2252  Use environment variables or secret managers (...
#
# [501 rows x 7 columns]
